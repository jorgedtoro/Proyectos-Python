# %%
import pandas as pd
import numpy as np
import os
import sys
import shutil
import time
from random import randint
import xlrd
import openpyxl

# %%
#cargamos datos de minderest
ruta = 'C:/Users/67075622/OneDrive - El Corte Inglés, S.A/Python/Pricing/'
archivo = 'Datos Minderest.xlsx'
df = pd.read_excel(ruta + archivo)

# %%
df
# Out:
#                           Retailer Country            SKU  \
# 0                 elcorteingles_es   SPAIN  1015215003623
# 1                 elcorteingles_es   SPAIN  1015216118032
# 2                        amazon.es   SPAIN  1015215582865
# 3                        amazon.es   SPAIN  1015215579051
# 4                 elcorteingles_es   SPAIN  1028645002016
# ...                            ...     ...            ...
# 22182          fnac.es/marketplace   SPAIN  1028611111111
# 22183  carrefour-noalimentacion_es   SPAIN  1028611111111
# 22184                    amazon.es   SPAIN  1028611111111
# 22185                   samsung_es   SPAIN  1028611111111
# 22186                pccomponentes   SPAIN  1028611111111
#
#                                                     Name         Brand  \
# 0      Sobremesa Asus S300MA-710700006T, i7, 16GB, 51...          asus
# 1      "Monitor PC 61,2 cm (24,1"") ASUS ProArt PA248...          asus
# ...
